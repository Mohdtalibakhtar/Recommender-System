# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import re
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
triplets=pd.read_table("kaggle_visible_evaluation_triplets.txt")

# %%
triplets.columns
# Out:
# Index(['fd50c4007b68a3737fe052d5a4f78ce8aa117f3d', 'SOBONKR12A58A7A7E0', '1'], dtype='object')

# %%
triplets=triplets.rename(columns={'fd50c4007b68a3737fe052d5a4f78ce8aa117f3d':'user_id','SOBONKR12A58A7A7E0':'song_id','1':'no.of times listened'})

# %%
triplets
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOFLJQZ12A6D4FADA6
# 2        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOHTKMO12AB01843B0
# 3        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SODQZCY12A6D4F9D11
# 4        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOXLOQG12AF72A2D55
# ...                                           ...                 ...
# 1450927  5e650759ebf89012044c6d52121eeada8b0ec814  SOVLNXV12A6D4F706E
# 1450928  5e650759ebf89012044c6d52121eeada8b0ec814  SOVDSJC12A58A7A271
# 1450929  5e650759ebf89012044c6d52121eeada8b0ec814  SOBRHVR12A8C133F35
# 1450930  5e650759ebf89012044c6d52121eeada8b0ec814  SOMGVYU12A8C1314FF
# 1450931  5e650759ebf89012044c6d52121eeada8b0ec814  SOTCMDJ12A6D4F8528
#
#          no.of times listened
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 1450927                     1
# 1450928                     2
# 1450929                     2
# 1450930                     2
# 1450931                     3
#
# [1450932 rows x 3 columns]

# %%
triplets.shape
# Out:
# (1450932, 3)

# %%
unique_tracks=pd.read_csv('unique_tracks.txt',sep='<SEP>',names=['track_id','song_id','artist_name','release'])

# %%
unique_tracks
# Out:
#                   track_id             song_id       artist_name  \
# 0       TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat
# 1       TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti
# 2       TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke
# 3       TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava
# 4       TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic
# ...                    ...                 ...               ...
# 999995  TRYYYUS12903CD2DF0  SOTXAME12AB018F136      Kiko Navarro
# 999996  TRYYYJO128F426DA37  SOXQYIQ12A8C137FBB     Kuldeep Manak
# 999997  TRYYYMG128F4260ECA  SOHODZI12A8C137BB3    Gabriel Le Mar
# 999998  TRYYYDJ128F9310A21  SOLXGOR12A81C21EB7             Elude
# 999999  TRYYYVU12903CD01E3  SOWXJXQ12AB0189F43             Texta
#
#                                      release
# 0                               Silent Night
# 1                                Tanssi vaan
# 2                          No One Could Ever
# 3                             Si Vos QuerÃ©s
# 4                           Tangle Of Aspens
# ...                                      ...
# 999995                       O Samba Da Vida
# 999996                          Jago Chhadeo
# 999997                               Novemba
# 999998                               Faraday
# 999999  Fernweh feat. Sektion KuchikÃ¤schtli
#
# [1000000 rows x 4 columns]

# %%
songs=pd.read_csv('kaggle_songs.txt')

# %%
songs.columns=['song_id']

# %%
songs
# Out:
#                           song_id
# 0            SOAAADE12A6D4F80CC 2
# 1            SOAAADF12A8C13DF62 3
# 2            SOAAADZ12A8C1334FB 4
# 3            SOAAAFI12A6D4F9C66 5
# 4            SOAAAGK12AB0189572 6
# ...                           ...
# 386207  SOZZZRJ12AB0187A75 386209
# 386208  SOZZZRV12A8C1361F1 386210
# 386209  SOZZZSR12AB01854CD 386211
# 386210  SOZZZWD12A6D4F6624 386212
# 386211  SOZZZWN12AF72A1E29 386213
#
# [386212 rows x 1 columns]

# %%
users=pd.read_csv('kaggle_users.txt')

# %%
users.columns=['user_id']

# %%
users
# Out:
#                                          user_id
# 0       d7083f5e1d50c264277d624340edaaf3dc16095b
# 1       d68dc6fc25248234590d7668a11e3335534ae4b4
# 2       9be82340a8b5ef32357fe5af957ccd54736ece95
# 3       841b2394ae3a9febbd6b06497b4a8ee8eb24b7f8
# 4       91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62
# ...                                          ...
# 109994  07f2f354a2a4390624e0d04e4a555ef67e98f673
# 109995  fe752b1aa2a12dbc203c37b70881d88481c655f1
# 109996  ab79461415bb9db956def3a897886d0754ddddfb
# 109997  fc072bde2043756ea30ff07e4a5311e34825b4df
# 109998  5e650759ebf89012044c6d52121eeada8b0ec814
#
# [109999 rows x 1 columns]

# %%
print(triplets.shape)
print(unique_tracks.shape)
# Out:
# (1450932, 3)
# (1000000, 4)

# %%
triplets
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOFLJQZ12A6D4FADA6
# 2        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOHTKMO12AB01843B0
# 3        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SODQZCY12A6D4F9D11
# 4        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOXLOQG12AF72A2D55
# ...                                           ...                 ...
# 1450927  5e650759ebf89012044c6d52121eeada8b0ec814  SOVLNXV12A6D4F706E
# 1450928  5e650759ebf89012044c6d52121eeada8b0ec814  SOVDSJC12A58A7A271
# 1450929  5e650759ebf89012044c6d52121eeada8b0ec814  SOBRHVR12A8C133F35
# 1450930  5e650759ebf89012044c6d52121eeada8b0ec814  SOMGVYU12A8C1314FF
# 1450931  5e650759ebf89012044c6d52121eeada8b0ec814  SOTCMDJ12A6D4F8528
#
#          no.of times listened
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 1450927                     1
# 1450928                     2
# 1450929                     2
# 1450930                     2
# 1450931                     3
#
# [1450932 rows x 3 columns]

# %%
unique_tracks
# Out:
#                   track_id             song_id       artist_name  \
# 0       TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat
# 1       TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti
# 2       TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke
# 3       TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava
# 4       TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic
# ...                    ...                 ...               ...
# 999995  TRYYYUS12903CD2DF0  SOTXAME12AB018F136      Kiko Navarro
# 999996  TRYYYJO128F426DA37  SOXQYIQ12A8C137FBB     Kuldeep Manak
# 999997  TRYYYMG128F4260ECA  SOHODZI12A8C137BB3    Gabriel Le Mar
# 999998  TRYYYDJ128F9310A21  SOLXGOR12A81C21EB7             Elude
# 999999  TRYYYVU12903CD01E3  SOWXJXQ12AB0189F43             Texta
#
#                                      release
# 0                               Silent Night
# 1                                Tanssi vaan
# 2                          No One Could Ever
# 3                             Si Vos QuerÃ©s
# 4                           Tangle Of Aspens
# ...                                      ...
# 999995                       O Samba Da Vida
# 999996                          Jago Chhadeo
# 999997                               Novemba
# 999998                               Faraday
# 999999  Fernweh feat. Sektion KuchikÃ¤schtli
#
# [1000000 rows x 4 columns]

# %%
df=pd.merge(triplets,unique_tracks,on='song_id')
df
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1        248378ac27e1745d6a9d59392b7dc5b02a6186a6  SOEGIYH12A6D4FC0E3
# 2        7c49f3e11a6fce79ae60b44df2a3edcf6eb2e163  SOEGIYH12A6D4FC0E3
# 3        8061f61372876878c2d67bc49b3ddbd2c83d69e2  SOEGIYH12A6D4FC0E3
# 4        d47c829c4ff6270f9ab82ca36b2805951b62a208  SOEGIYH12A6D4FC0E3
# ...                                           ...                 ...
# 1491946  9d2f78e2bda5a004879d3ee53ee7de5cdf99c730  SOIDWNE12A8C13E669
# 1491947  987b654b09b239f7c47751e0cfaa2990834cbb55  SOATNWN12A6D4F826F
# 1491948  987b654b09b239f7c47751e0cfaa2990834cbb55  SOGMCFE12AB018A3A1
# 1491949  fc072bde2043756ea30ff07e4a5311e34825b4df  SOBAOTU12A6D4F7A68
# 1491950  fc072bde2043756ea30ff07e4a5311e34825b4df  SOGWSIO12A8C133A5B
#
#          no.of times listened            track_id  \
# 0                           1  TRLGMFJ128F4217DBE
# 1                           1  TRLGMFJ128F4217DBE
# 2                           1  TRLGMFJ128F4217DBE
# 3                           1  TRLGMFJ128F4217DBE
# 4                           1  TRLGMFJ128F4217DBE
# ...                       ...                 ...
# 1491946                     1  TRZHWHD128F42B9D11
# 1491947                     1  TRNBQWA128F145DB74
# 1491948                     3  TRIWGAI12903CDF710
# 1491949                     1  TRMPODL128F4228DE1
# 1491950                     1  TRBOBJP128F423F082
#
#                                                artist_name  \
# 0        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 1        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 2        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 3        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# ...                                                    ...
# 1491946                                  Our Broken Garden
# 1491947                                             Emilio
# 1491948                                       Morbid Angel
# 1491949                                            Gus Gus
# 1491950                                            Gus Gus
#
#                                                    release
# 0        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 1        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 2        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 4        Horn Concerto No. 4 in E flat K495: II. Romanc...
# ...                                                    ...
# 1491946                                       The Blinding
# 1491947                                       Como A Nadie
# 1491948            Victorious March Of Reign The Conqueror
# 1491949                                   Call of the Wild
# 1491950                                            Snoozer
#
# [1491951 rows x 6 columns]

# %%
#Removing track_id column as it is not needed for us 
df.drop('track_id', axis=1, inplace=True)

# %%
df
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1        248378ac27e1745d6a9d59392b7dc5b02a6186a6  SOEGIYH12A6D4FC0E3
# 2        7c49f3e11a6fce79ae60b44df2a3edcf6eb2e163  SOEGIYH12A6D4FC0E3
# 3        8061f61372876878c2d67bc49b3ddbd2c83d69e2  SOEGIYH12A6D4FC0E3
# 4        d47c829c4ff6270f9ab82ca36b2805951b62a208  SOEGIYH12A6D4FC0E3
# ...                                           ...                 ...
# 1491946  9d2f78e2bda5a004879d3ee53ee7de5cdf99c730  SOIDWNE12A8C13E669
# 1491947  987b654b09b239f7c47751e0cfaa2990834cbb55  SOATNWN12A6D4F826F
# 1491948  987b654b09b239f7c47751e0cfaa2990834cbb55  SOGMCFE12AB018A3A1
# 1491949  fc072bde2043756ea30ff07e4a5311e34825b4df  SOBAOTU12A6D4F7A68
# 1491950  fc072bde2043756ea30ff07e4a5311e34825b4df  SOGWSIO12A8C133A5B
#
#          no.of times listened  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 1491946                     1
# 1491947                     1
# 1491948                     3
# 1491949                     1
# 1491950                     1
#
#                                                artist_name  \
# 0        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 1        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 2        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 3        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# ...                                                    ...
# 1491946                                  Our Broken Garden
# 1491947                                             Emilio
# 1491948                                       Morbid Angel
# 1491949                                            Gus Gus
# 1491950                                            Gus Gus
#
#                                                    release
# 0        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 1        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 2        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 4        Horn Concerto No. 4 in E flat K495: II. Romanc...
# ...                                                    ...
# 1491946                                       The Blinding
# 1491947                                       Como A Nadie
# 1491948            Victorious March Of Reign The Conqueror
# 1491949                                   Call of the Wild
# 1491950                                            Snoozer
#
# [1491951 rows x 5 columns]

# %%
df.describe()
#it shows the frequency of the songs
# Out:
#        no.of times listened
# count          1.491951e+06
# mean           3.179720e+00
# std            7.015025e+00
# min            1.000000e+00
# 25%            1.000000e+00
# 50%            1.000000e+00
# 75%            3.000000e+00
# max            9.230000e+02

# %%
df.dtypes
# Out:
# user_id                 object
# song_id                 object
# no.of times listened     int64
# artist_name             object
# release                 object
# dtype: object

# %%
print('Total no.of songs :',df['song_id'].nunique())
print('Total no.of users :',df['user_id'].nunique())
print('Total no.of artists :',df['artist_name'].nunique())
# Out:
# Total no.of songs : 163206
# Total no.of users : 110000
# Total no.of artists : 28367

# %% [markdown]
# ### checking for null values

# %%
print(df.isna().sum(),"\n")
print('percentage of null values'"\n\n\n",df.isna().sum()/len(df)*100)
# Out:
# user_id                 0
# song_id                 0
# no.of times listened    0
# artist_name             0
# release                 1
# dtype: int64
#
# percentage of null values
#
#
#  user_id                 0.000000
# song_id                 0.000000
# no.of times listened    0.000000
# artist_name             0.000000
# release                 0.000067
# dtype: float64

# %% [markdown]
# As there is only 1 null value in release feature we can drop that column

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
#checking for null values after dropping null values 
print(df.isna().sum(),"\n")
print('percentage of null values'"\n\n",df.isna().sum()/len(df)*100)
# Out:
# user_id                 0
# song_id                 0
# no.of times listened    0
# artist_name             0
# release                 0
# dtype: int64
#
# percentage of null values
#
#  user_id                 0.0
# song_id                 0.0
# no.of times listened    0.0
# artist_name             0.0
# release                 0.0
# dtype: float64

# %% [markdown]
# ### checking for duplicates in out dataframe

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1491946    False
# 1491947    False
# 1491948    False
# 1491949    False
# 1491950    False
# Length: 1491950, dtype: bool

# %% [markdown]
# ### dropping duplicates

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
 df.shape
# Out:
# (1456563, 5)

# %% [markdown]
# ### sorting columns based on no.of times listened

# %%
df.sort_values('no.of times listened',ascending=True)
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 893572   23614884aa75fe96d99a36a775aeda1b531830b2  SOFLGUD12A6701F7FD
# 893574   d2e8d8aeb220950b4ddfc7c5e648d439a9965eed  SOFLGUD12A6701F7FD
# 893575   ff499594b217036334d3b300e03f9c61ae7b9df9  SOFLGUD12A6701F7FD
# 893576   40f25f9031233352e9e9c5d2e52aaae4dafd1ba9  SOFLGUD12A6701F7FD
# ...                                           ...                 ...
# 1424225  a86e68128c6a48d3392db22ce1151a3bdccf5fcf  SOFVLYV12A8C145D8F
# 526513   69ad6b6a1d14d740eb8c2f013a19c1f8048cecde  SONGOJV12AF729AEBD
# 641625   2d9ea6058d0872ccdc5b1c5c685758bb9c55f0a3  SOAOXTG12A67021AA7
# 679629   a1cc4d088600df2db42e6a305974675ffe8c905d  SOPMHHE12AB01845F6
# 1491875  22bb29714137fa47083963c30e1a26f1bf517e7d  SOXTUWG12AB018A2E2
#
#          no.of times listened  \
# 0                           1
# 893572                      1
# 893574                      1
# 893575                      1
# 893576                      1
# ...                       ...
# 1424225                   537
# 526513                    582
# 641625                    597
# 679629                    646
# 1491875                   923
#
#                                                artist_name  \
# 0        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 893572                                           Frou Frou
# 893574                                           Frou Frou
# 893575                                           Frou Frou
# 893576                                           Frou Frou
# ...                                                    ...
# 1424225                                                Us3
# 526513                                               Queen
# 641625                        Ms. Dynamite / Kymani Marley
# 679629                                      The Beach Boys
# 1491875                                            Kilgore
#
#                                                    release
# 0        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 893572                              Holding Out For A Hero
# 893574                              Holding Out For A Hero
# 893575                              Holding Out For A Hero
# 893576                              Holding Out For A Hero
# ...                                                    ...
# 1424225                                Believe In Yourself
# 526513                                    Somebody To Love
# 641625                                      Seed Will Grow
# 679629                        What Is a Young Girl Made of
# 1491875                    Drop The Hammer (Album Version)
#
# [1456563 rows x 5 columns]

# %%
#No.of times songs are played 
print(df[['no.of times listened']].value_counts())
# Out:
# no.of times listened
# 1                       842217
# 2                       214701
# 3                        96189
# 5                        73737
# 4                        55407
#                          ...
# 262                          1
# 187                          1
# 259                          1
# 189                          1
# 923                          1
# Length: 299, dtype: int64

# %% [markdown]
# ### Total number of artists

# %%
 
print("total no.of artists are :",df['artist_name'].nunique())
# Out:
# total no.of artists are : 28366

# %% [markdown]
# ### Total number of unique releases

# %%
df['release'].unique()
# Out:
# array(['Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)',
#        'Tive Sim', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)',
#        ..., 'Victorious March Of Reign The Conqueror', 'Call of the Wild',
#        'Snoozer'], dtype=object)

# %%
df['release'].nunique()
# Out:
# 137674

# %% [markdown]
# ### There are total of 28366 artists in the given data set

# %%
df['artist_name'].unique()
# Out:
# array(['Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner',
#        'Cartola', 'Lonnie Gordon', ..., 'P.Paul Fenech', 'Mystic Rhythms',
#        'H.e.a.t'], dtype=object)

# %% [markdown]
# ## Top 100 popular songs

# %%
popular_df=df[['artist_name','no.of times listened','release']]

# %%
popular_df.sort_values(by='no.of times listened',ascending=False)
# Out:
#                           artist_name  no.of times listened  \
# 1491875                       Kilgore                   923
# 679629                 The Beach Boys                   646
# 641625   Ms. Dynamite / Kymani Marley                   597
# 526513                          Queen                   582
# 1424225                           Us3                   537
# ...                               ...                   ...
# 668679                   Dean Evenson                     1
# 668680                   Dean Evenson                     1
# 668681                   Dean Evenson                     1
# 668682                   Dean Evenson                     1
# 1491950                       Gus Gus                     1
#
#                                  release
# 1491875  Drop The Hammer (Album Version)
# 679629      What Is a Young Girl Made of
# 641625                    Seed Will Grow
# 526513                  Somebody To Love
# 1424225              Believe In Yourself
# ...                                  ...
# 668679                    Mossing Around
# 668680                    Mossing Around
# 668681                    Mossing Around
# 668682                    Mossing Around
# 1491950                          Snoozer
#
# [1456563 rows x 3 columns]

# %%
artist_popularity=popular_df.groupby(['artist_name'])['no.of times listened'].sum().sort_values(ascending=False)
artist_popularity
# Out:
# artist_name
# Kings Of Leon                35857
# Dwight Yoakam                35687
# BjÃ¶rk                       35210
# Coldplay                     32135
# Florence + The Machine       28224
#                              ...
# Beto y sus Canarios              1
# L'Arc-en-ciel                    1
# Nate Dogg feat. Big Chuck        1
# Treklang Reggae                  1
# Home Run                         1
# Name: no.of times listened, Length: 28366, dtype: int64

# %% [markdown]
# ### These  are the top 100 songs based on popularity

# %%
song_popularity=popular_df.groupby(['release'])['no.of times listened'].sum().sort_values(ascending=False)

# %%
song_popularity
# Out:
# release
# You're The One                                                         35737
# Undo                                                                   33179
# Revelry                                                                24359
# Sehr kosmisch                                                          19454
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)    17115
#                                                                        ...
# Hush (Album Version)                                                       1
# Penny To My Name (Album Version)                                           1
# That Was Then                                                              1
# Penny We                                                                   1
# Esta Es Una Noche De Rock&Roll                                             1
# Name: no.of times listened, Length: 137674, dtype: int64

# %% [markdown]
# ###  we can see the no.of songs played per person

# %%
songs_per_person=df.groupby(['user_id'])['no.of times listened'].sum()

# %%
songs_per_person
# Out:
# user_id
# 00007a02388c208ea7176479f6ae06f8224355b3     13
# 00014a76ed063e1a749171a253bca9d9a0ff1782     24
# 00015189668691680bb1a2e58afde1541ec92ced    101
# 0001ff7aa2667c8d8b945317b88adaed1c0b9dc2     12
# 00020fcd8b01986a6a85b896ccde6c49f35142ad     44
#                                            ...
# fffdef71f13352e9cff769f1d96f5ccf90f8955e     10
# fffe29116f96c97b47a5dabdd406784ad0ba6f30     10
# fffe5b73c50c72ca9c54947efac1fcacf59c4a17    108
# fffed0bee753cd78494011b8b55dafd4f5c7e5ff     76
# ffff07d7d9bb187aa58c7b81b3d3f35e7cf7c0ee     42
# Name: no.of times listened, Length: 110000, dtype: int64

# %%
df
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1        248378ac27e1745d6a9d59392b7dc5b02a6186a6  SOEGIYH12A6D4FC0E3
# 2        7c49f3e11a6fce79ae60b44df2a3edcf6eb2e163  SOEGIYH12A6D4FC0E3
# 3        8061f61372876878c2d67bc49b3ddbd2c83d69e2  SOEGIYH12A6D4FC0E3
# 4        d47c829c4ff6270f9ab82ca36b2805951b62a208  SOEGIYH12A6D4FC0E3
# ...                                           ...                 ...
# 1491946  9d2f78e2bda5a004879d3ee53ee7de5cdf99c730  SOIDWNE12A8C13E669
# 1491947  987b654b09b239f7c47751e0cfaa2990834cbb55  SOATNWN12A6D4F826F
# 1491948  987b654b09b239f7c47751e0cfaa2990834cbb55  SOGMCFE12AB018A3A1
# 1491949  fc072bde2043756ea30ff07e4a5311e34825b4df  SOBAOTU12A6D4F7A68
# 1491950  fc072bde2043756ea30ff07e4a5311e34825b4df  SOGWSIO12A8C133A5B
#
#          no.of times listened  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 1491946                     1
# 1491947                     1
# 1491948                     3
# 1491949                     1
# 1491950                     1
#
#                                                artist_name  \
# 0        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 1        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 2        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 3        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# ...                                                    ...
# 1491946                                  Our Broken Garden
# 1491947                                             Emilio
# 1491948                                       Morbid Angel
# 1491949                                            Gus Gus
# 1491950                                            Gus Gus
#
#                                                    release
# 0        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 1        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 2        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 4        Horn Concerto No. 4 in E flat K495: II. Romanc...
# ...                                                    ...
# 1491946                                       The Blinding
# 1491947                                       Como A Nadie
# 1491948            Victorious March Of Reign The Conqueror
# 1491949                                   Call of the Wild
# 1491950                                            Snoozer
#
# [1456563 rows x 5 columns]

# %%
songs_per_person.sort_values(ascending=False)
# Out:
# user_id
# 090b841eaf56d343a26625c2c6d08b823927bc4f    1305
# 938c2632d43eeadb8a83a7cc254d014f9cea6afe    1280
# 1c5aa998482a40abfd020759e7d757eb6c510e72    1200
# c6150292374fb1dad89982367b3245dd5004c718    1192
# 5a9375e46a7e9b869058c7bc0e820e00d77f3e0b    1184
#                                             ...
# dc152fb9b0b72648dc10e6ed6effb3b148aa316a       5
# 717d34613ad93f04ea187a0fbe444561e96d1c84       5
# fa6894e991dba63dd2d5c5465c1e0f77ab62770b       5
# 342bf803141c8a84ccb04dae940477d8621ac73a       5
# 89b07df379827a871fb1e991e14f0918bf4ebc6b       5
# Name: no.of times listened, Length: 110000, dtype: int64

# %%
songs_per_person.describe()
# Out:
# count    110000.000000
# mean         42.186709
# std          53.487815
# min           5.000000
# 25%          13.000000
# 50%          26.000000
# 75%          50.000000
# max        1305.000000
# Name: no.of times listened, dtype: float64

# %% [markdown]
# ###  Maximum songs listened by a person are 1305
# ### Minimum songs listened by person are 5

# %%
songs_per_person_df=songs_per_person.head(10)

# %%
ax = sns.distplot(songs_per_person,bins=100,kde=True,color='skyblue',hist_kws={"linewidth": 20,'alpha':1})

# %% [markdown]
# By this plot we can say that many people listened songs 0 to 200 times.

# %% [markdown]
# ## Distribution of frequency

# %%
ax = sns.distplot(df['no.of times listened'],bins=100,kde=True,color='skyblue',hist_kws={"linewidth": 15,'alpha':1})

ax.set(xlabel='no.of times listened', ylabel='density')
# Out:
# [Text(0,0.5,'density'), Text(0.5,0,'no.of times listened')]

# %% [markdown]
# By this plot we can say that there are only few people listened songs more than 100 times and many people listenes songs less times

# %%
sns.boxplot(df['no.of times listened'])

# %% [markdown]
# By this plot we can say that there are some outliers.
# we can remove the outliers by IQR method.

# %%
plt.figure(figsize=(15,5))
sns.kdeplot(df['no.of times listened'])

# %%
plt.figure(figsize=(15,5))
sns.boxplot(df['no.of times listened'])

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize=(20,5))
sns.barplot('no.of times listened',y='song_id' , data = df, palette ='plasma')

# %%
plt.figure(figsize=(20,5))
sns.barplot('no.of times listened',y='user_id' , data = df, palette ='plasma')

# %% [markdown]
# ### Artist popularity

# %%
artist_df=popular_df[['artist_name']]

# %%
artist_df
# Out:
#                                                artist_name
# 0        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 1        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 2        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 3        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# ...                                                    ...
# 1491946                                  Our Broken Garden
# 1491947                                             Emilio
# 1491948                                       Morbid Angel
# 1491949                                            Gus Gus
# 1491950                                            Gus Gus
#
# [1456563 rows x 1 columns]

# %%
artist_popularity=artist_df.iloc[:,0]

# %%
artist_popularity.sort_values()
# Out:
# 1145697     !!!
# 1145731     !!!
# 1145730     !!!
# 1145729     !!!
# 1203188     !!!
#            ...
# 1452907    Ã�on
# 1452908    Ã�on
# 1457051    Ã�on
# 1391297    Ã�on
# 1452906    Ã�on
# Name: artist_name, Length: 1456563, dtype: object

# %%
df
# Out:
#                                           user_id             song_id  \
# 0        fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1        248378ac27e1745d6a9d59392b7dc5b02a6186a6  SOEGIYH12A6D4FC0E3
# 2        7c49f3e11a6fce79ae60b44df2a3edcf6eb2e163  SOEGIYH12A6D4FC0E3
# 3        8061f61372876878c2d67bc49b3ddbd2c83d69e2  SOEGIYH12A6D4FC0E3
# 4        d47c829c4ff6270f9ab82ca36b2805951b62a208  SOEGIYH12A6D4FC0E3
# ...                                           ...                 ...
# 1491946  9d2f78e2bda5a004879d3ee53ee7de5cdf99c730  SOIDWNE12A8C13E669
# 1491947  987b654b09b239f7c47751e0cfaa2990834cbb55  SOATNWN12A6D4F826F
# 1491948  987b654b09b239f7c47751e0cfaa2990834cbb55  SOGMCFE12AB018A3A1
# 1491949  fc072bde2043756ea30ff07e4a5311e34825b4df  SOBAOTU12A6D4F7A68
# 1491950  fc072bde2043756ea30ff07e4a5311e34825b4df  SOGWSIO12A8C133A5B
#
#          no.of times listened  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 1491946                     1
# 1491947                     1
# 1491948                     3
# 1491949                     1
# 1491950                     1
#
#                                                artist_name  \
# 0        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 1        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 2        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 3        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4        Barry Tuckwell/Academy of St Martin-in-the-Fie...
# ...                                                    ...
# 1491946                                  Our Broken Garden
# 1491947                                             Emilio
# 1491948                                       Morbid Angel
# 1491949                                            Gus Gus
# 1491950                                            Gus Gus
#
#                                                    release
# 0        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 1        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 2        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3        Horn Concerto No. 4 in E flat K495: II. Romanc...
# 4        Horn Concerto No. 4 in E flat K495: II. Romanc...
# ...                                                    ...
# 1491946                                       The Blinding
# 1491947                                       Como A Nadie
# 1491948            Victorious March Of Reign The Conqueror
# 1491949                                   Call of the Wild
# 1491950                                            Snoozer
#
# [1456563 rows x 5 columns]

# %%
df['user_id'].nunique()
# Out:
# 110000

# %%
df['song_id'].nunique()
# Out:
# 163205

# %%
song=df.drop_duplicates(['user_id','song_id','artist_name'])
song=song.reset_index(drop=True)

# %%
song.head()
# Out:
#                                     user_id             song_id  \
# 0  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3
# 1  248378ac27e1745d6a9d59392b7dc5b02a6186a6  SOEGIYH12A6D4FC0E3
# 2  7c49f3e11a6fce79ae60b44df2a3edcf6eb2e163  SOEGIYH12A6D4FC0E3
# 3  8061f61372876878c2d67bc49b3ddbd2c83d69e2  SOEGIYH12A6D4FC0E3
# 4  d47c829c4ff6270f9ab82ca36b2805951b62a208  SOEGIYH12A6D4FC0E3
#
#    no.of times listened                                        artist_name  \
# 0                     1  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 1                     1  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 2                     1  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 3                     1  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4                     1  Barry Tuckwell/Academy of St Martin-in-the-Fie...
#
#                                              release
# 0  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 1  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 2  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 4  Horn Concerto No. 4 in E flat K495: II. Romanc...

# %%
song.shape
# Out:
# (1451759, 5)

# %%
song['user_id'].shape
# Out:
# (1451759,)

# %%
song['song_id'].shape
# Out:
# (1451759,)

# %%
song_pivot=song.pivot(index='user_id',columns='song_id',values='no.of times listened')
song_pivot=song_pivot.fillna(0)
song_pivot.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-4a897c2a8ab1> in <module>
# ----> 1 song_pivot=song.pivot(index='user_id',columns='song_id',values='no.of times listened')
#       2 song_pivot=song_pivot.fillna(0)
#       3 song_pivot.shape
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6672         from pandas.core.reshape.pivot import pivot
#    6673
# -> 6674         return pivot(self, index=index, columns=columns, values=values)
#    6675
#    6676     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 477     return indexed.unstack(columns)
#     478
#     479
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3888         from pandas.core.reshape.reshape import unstack
#    3889
# -> 3890         return unstack(self, level, fill_value)
#    3891
#    3892     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     422         if is_extension_array_dtype(obj.dtype):
#     423             return _unstack_extension_series(obj, level, fill_value)
# --> 424         unstacker = _Unstacker(
#     425             obj.index, level=level, constructor=obj._constructor_expanddim,
#     426         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     118             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     119
# --> 120         self._make_selectors()
#     121
#     122     @cache_readonly
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     164         selector = self.sorted_labels[-1] + stride * comp_index + self.lift
#     165         mask = np.zeros(np.prod(self.full_shape), dtype=bool)
# --> 166         mask.put(selector, True)
#     167
#     168         if mask.sum() < len(self.index):
#
# IndexError: index 772779284 is out of bounds for axis 0 with size 772680816

# %%
song_pivot.head()
# Out:
# song_id                                   SOACRJG12A8C137A8D  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOATCSU12A8C13393A  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SODQZCY12A6D4F9D11  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SODSKZZ12AB0188524  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOEFCDJ12AB0185FA0  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOEGIYH12A6D4FC0E3  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 1.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOFLJQZ12A6D4FADA6  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 2.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 2.0
#
# song_id                                   SOFRQTD12A81C233C0  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOHEKND12A8AE481D0  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOHTKMO12AB01843B0  ...  \
# user_id                                                       ...
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0  ...
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 8.0  ...
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0  ...
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 2.0  ...
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0  ...
#
# song_id                                   SONJVYU12A8AE44F9E  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SONZTNP12A8C1321DF  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOPFVWP12A6D4FC636  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOPSVVG12A8C13B444  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOSOUKN12A8C13AB79  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOUQERE12A58A75633  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOUVUHC12A67020E3B  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOVVLKF12A8C1424F0  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOXLOQG12AF72A2D55  \
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# song_id                                   SOZPZGN12A8C135B45
# user_id
# 0003d5245414b9c6244046543a06f601bfc97949                 0.0
# 000dd7137b511a0c6e45880de551c6a7019ee4c3                 0.0
# 001db6e9e8f569b3d7d24b49db576d179f290fd2                 0.0
# 0029bec66fe7ce2a396c2f78b35aedcd2b9d3e4a                 0.0
# 002dfbc3c073b55a64a4abab34c0ca1f13897f1c                 0.0
#
# [5 rows x 22 columns]

# %%
from sklearn.neighbors import NearestNeighbors
knn=NearestNeighbors(n_neighbors=10,metric='cosine')
model_user=knn.fit(song_pivot)

# %%
def findRecomendationsUsers(model, matrix, data, query_index):
    distances,indices = model.kneighbors([matrix.iloc[query_index, :]], n_neighbors = 10)
    for i in range(0, len(distances.flatten())):
        if i == 0:
            print("Searching recommendation for user: ", matrix.index[query_index])
        else:
            rows = data.loc[data['user_id'] == matrix.index[indices.flatten()[i]] ]
            for item in rows.values:      
              print("\n  User: ", item[0])
              print("    Play Count: ", item[2])  
              print("    Song: ",  item[3])

# %%
query_index = np.random.choice(song_pivot.shape[0])
query_index
# Out:
# 5849

# %%
findRecomendationsUsers(model_user, song_pivot, df, query_index)
# Out:
# Searching recommendation for user:  af8b266210f9f15c6edd989d31fd48342b128909
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Beastie Boys
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  3
#     Song:  OneRepublic
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  2
#     Song:  Kings Of Leon
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  3
#     Song:  Kings Of Leon
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Charttraxx Karaoke
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  2
#     Song:  Train
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Five Iron Frenzy
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Dino Merlin
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Sonny Boy Williamson
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Randy Crawford
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  The Crests
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Owl City
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Jason Mraz & Colbie Caillat
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Simon Harris
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Foolish Things
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Justin Bieber
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Cradle Of Filth
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Linkin Park
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Paramore
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Jack Johnson
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Band Of Horses
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Mya
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Young Bleed
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Bill Withers
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Frumpies
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Polly Paulusma
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  DecembeRadio
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Jules Shear
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Green Day
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Andre Hazes
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Duncan Dhu
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  5
#     Song:  Brazilian Girls
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Nickelback
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  Nickelback
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  The Alter Boys
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  6
#     Song:  FRANK T
#
#   User:  c61c1d38c075ce0090bf568f9020d42bd62fb937
#     Play Count:  1
#     Song:  DUNCAN SHEIK
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  7
#     Song:  Beastie Boys
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  1
#     Song:  The Swinging Blue Jeans
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  3
#     Song:  Anna Abreu
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  5
#     Song:  CJ Stone
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  4
#     Song:  Dio
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  1
#     Song:  Blacklisted
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  2
#     Song:  Gregor Samsa
#
#   User:  b05e1a539c37a6f11af1cce559954a9e878c7c8b
#     Play Count:  1
#     Song:  Commander Tom
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  2
#     Song:  Beastie Boys
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  1
#     Song:  Justin Timberlake
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  2
#     Song:  Coko featuring Kirk Franklin
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  1
#     Song:  Kiss
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  3
#     Song:  Religious Knives
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  1
#     Song:  Lydia Lunch
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  5
#     Song:  !!!
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  1
#     Song:  Dimmu Borgir
#
#   User:  90bf95dac1989e74c3ac86ef98cd75e411ebe70d
#     Play Count:  1
#     Song:  Flux Pavilion
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  3
#     Song:  Beastie Boys
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  10
#     Song:  BjÃ¶rk
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  BjÃ¶rk
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Fergie
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Diam's
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  2
#     Song:  BeyoncÃ©
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Black Eyed Peas
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Kruiz
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  KMD
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Colt Ford
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Alberto Plaza
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  4
#     Song:  Willie Gonzalez
#
#   User:  9d147b6c1a3555c9ebde7efa368671e6c7a3b40e
#     Play Count:  1
#     Song:  Black Diamond Heavies
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  53
#     Song:  Beastie Boys
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  2
#     Song:  Fall Out Boy
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Dance Gavin Dance
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  2
#     Song:  The Kills
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Panic At The Disco
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Panic! At The Disco
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  9
#     Song:  My Chemical Romance
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  5
#     Song:  The Mars Volta
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Fall Out Boy
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Depeche Mode
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  2
#     Song:  Los Lobos
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  6
#     Song:  Modest Mouse
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  The Kills
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Emarosa
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  1
#     Song:  Dance Gavin Dance
#
#   User:  b8ad272f2d7fe11a05cb22b3805773a42f304ebe
#     Play Count:  5
#     Song:  From First to Last
#
#   User:  1e07a086bf1e98d54d2063647f627c26e0337740
#     Play Count:  7
#     Song:  Beastie Boys
#
#   User:  1e07a086bf1e98d54d2063647f627c26e0337740
#     Play Count:  3
#     Song:  Jake Hess
#
#   User:  1e07a086bf1e98d54d2063647f627c26e0337740
#     Play Count:  6
#     Song:  Shania Twain
#
#   User:  1e07a086bf1e98d54d2063647f627c26e0337740
#     Play Count:  1
#     Song:  Jackson Browne
#
#   User:  1e07a086bf1e98d54d2063647f627c26e0337740
#     Play Count:  2
#     Song:  David Lee Garza
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  36
#     Song:  Beastie Boys
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  20
#     Song:  Kid Cudi / Kanye West / Common
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  3
#     Song:  Lady GaGa / Colby O'Donis
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  38
#     Song:  Ron Carter
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  3
#     Song:  3OH!3
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  13
#     Song:  Hot Chocolate
#
#   User:  b8aafed44315edb0cafa9a01598513e4d23bd05b
#     Play Count:  1
#     Song:  Rammstein
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Beastie Boys
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Octopus Project
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  2
#     Song:  Charlie Louvin
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Deadmau5
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Los AutÃ©nticos Decadentes
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  3
#     Song:  Jane's Addiction
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lady GaGa
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lady GaGa
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  2
#     Song:  Polly Paulusma
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Moon far away
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  El-P
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Jules Shear
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Cut Copy
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Catherine Zeta-Jones;RenÃ©e Zellweger;Taye Diggs
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lindisfarne
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Justice
#
#   User:  50685bd4c840149e9ed64edb996343e4de781409
#     Play Count:  1
#     Song:  Lily Allen
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Beastie Boys
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  2
#     Song:  The Crests
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Dj Sammy
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  11
#     Song:  Ron Carter
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Cosmo Vitelli
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Fall Out Boy
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Angels and Airwaves
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  10
#     Song:  Basshunter
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Chris Isaak
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Disturbed
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  5
#     Song:  Mutya Buena
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Big Daddy Weave
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  FM Static
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Daddy Yankee
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Geri Halliwell
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  2
#     Song:  Daniel Bedingfield
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  BjÃ¶rk
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  10
#     Song:  Neutral Milk Hotel
#
#   User:  f53fd9fd5b1f449a79f4d1e4155bc4a7ca88f3ab
#     Play Count:  1
#     Song:  Caesars
